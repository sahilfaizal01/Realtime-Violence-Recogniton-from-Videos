# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_215.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_871.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_849.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_603.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_248.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_688.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_656.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_102.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_995.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_827.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_804.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_210.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_941.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_905.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_761.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_771.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_830.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_129.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_800.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_861.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_84.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_516.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_894.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_202.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_275.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_919.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_856.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_842.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_884.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_962.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_307.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_282.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_434.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_501.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_30.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_13.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_161.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_655.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_225.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_213.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_349.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_339.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_442.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_678.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_93.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_255.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_192.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_366.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_404.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_987.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_947.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_586.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_98.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_552.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_68.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_707.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_758.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_157.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_523.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_88.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_885.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_695.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_466.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_836.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_48.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_499.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_630.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_79.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_408.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_648.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_826.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_173.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_474.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_314.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_797.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_199.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_944.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_502.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_521.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_374.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_740.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_297.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_70.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_558.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_397.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_271.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_864.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_590.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_226.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_918.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_110.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_714.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_511.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_412.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_513.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_548.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_924.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_354.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_914.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_599.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_952.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_250.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_130.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_857.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_224.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_955.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_684.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_468.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_133.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_310.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_182.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_405.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_270.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_978.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_687.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_748.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_296.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_1.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_986.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_19.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_669.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_163.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_203.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_64.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_326.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_975.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_935.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_637.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_420.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_249.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_570.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_44.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_667.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_222.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_186.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_344.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_625.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_445.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_206.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_243.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_165.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_790.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_396.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_702.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_577.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_235.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_485.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_242.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_814.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_572.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_609.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_895.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_697.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_726.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_853.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_153.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_844.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_832.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_769.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_519.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_780.mp4
# /kaggle/input/violencerecogfeatures/video_files_paths.npy
# /kaggle/input/violencerecogfeatures/features.npy
# /kaggle/input/violencerecogfeatures/labels.npy
# /kaggle/input/violencerecogfeatures/model.h5

# %%
import os 
import tensorflow as tf
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
MyDrive = '/kaggle/working'

PROJECT_DIR = '../input/real-life-violence-situations-dataset'
# !ls {PROJECT_DIR}
# Out:
# 'Real Life Violence Dataset'  'real life violence situations'

# %%
import cv2
import os
import imageio
import imgaug.augmenters as iaa
import imgaug as ia

IMG_SIZE = 128
ColorChannels = 3

def video_to_frames(video):
    vidcap = cv2.VideoCapture(video)
    
    import math
    rate = math.floor(vidcap.get(3))
    count = 0
    
    ImageFrames = []
    while vidcap.isOpened():
        ID = vidcap.get(1)
        success, image = vidcap.read()
        
        if success:
            # skipping frames to avoid duplications 
            if (ID % 7 == 0):
                flip = iaa.Fliplr(1.0)
                zoom = iaa.Affine(scale=1.3)
                random_brightness = iaa.Multiply((1, 1.3))
                rotate = iaa.Affine(rotate=(-25, 25))
                
                image_aug = flip(image = image)
                image_aug = random_brightness(image = image_aug)
                image_aug = zoom(image = image_aug)
                image_aug = rotate(image = image_aug)
                
                rgb_img = cv2.cvtColor(image_aug, cv2.COLOR_BGR2RGB)
                resized = cv2.resize(rgb_img, (IMG_SIZE, IMG_SIZE))
                ImageFrames.append(resized)
                
            count += 1
        else:
            break
    
    vidcap.release()
    
    return ImageFrames

# %%
# %%time
from tqdm import tqdm

VideoDataDir = PROJECT_DIR + '/Real Life Violence Dataset'
print('we have \n{} Violence videos \n{} NonViolence videos'.format(
              len(os.listdir(VideoDataDir + '/Violence')), 
              len(os.listdir(VideoDataDir + '/NonViolence'))))

X_original = []
y_original = []

CLASSES = ["NonViolence", "Violence"]

for category in os.listdir(VideoDataDir):
    path = os.path.join(VideoDataDir, category)
    class_num = CLASSES.index(category)
    for i, video in enumerate(tqdm(os.listdir(path)[0:400])):
        frames = video_to_frames(path + '/' + video)
        for j, frame in enumerate(frames):
            X_original.append(frame)
            y_original.append(class_num)
# Out:
# we have
# 1000 Violence videos
# 1000 NonViolence videos
# 100%|██████████| 400/400 [01:21<00:00,  4.89it/s]
# 100%|██████████| 400/400 [02:31<00:00,  2.63it/s]
# CPU times: user 9min 3s, sys: 55.1 s, total: 9min 59s
# Wall time: 3min 53s

# %%
import numpy as np
X_original = np.array(X_original).reshape(-1 , IMG_SIZE * IMG_SIZE * 3)
y_original = np.array(y_original)
len(X_original)
# Out:
# 15589

# %%
from sklearn.model_selection import StratifiedShuffleSplit

stratified_sample = StratifiedShuffleSplit(n_splits=2, test_size=0.3, random_state=73)

for train_index, test_index in stratified_sample.split(X_original, y_original):
    X_train, X_test = X_original[train_index], X_original[test_index]
    y_train, y_test = y_original[train_index], y_original[test_index]

X_train_nn = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255
X_test_nn = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255

# %%
IMG_SIZE = 128
ColorChannels = 3

# %%
import cv2
import matplotlib
matplotlib.use("Agg")

from keras.layers import Input
from keras.models import Model
from keras.layers.core import Dropout,Flatten,Dense

import matplotlib.pyplot as plt

# %%
from keras import regularizers
kernel_regularizer = regularizers.l2(0.0001)

from keras.applications import MobileNetV2

def load_layers():
    input_tensor = Input(shape=(IMG_SIZE, IMG_SIZE, ColorChannels))
    baseModel = MobileNetV2(pooling='avg',
                            include_top=False, 
                            input_tensor=input_tensor)
    
    headModel = baseModel.output   
    headModel = Dense(1, activation="sigmoid")(headModel)
    model = Model(inputs=baseModel.input, outputs=headModel)

    for layer in baseModel.layers:
        layer.trainable = False

    return model

# %%
model = load_layers()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step

# %%
model.load_weights('/kaggle/input/violencerecogfeatures/model.h5')

# %%
predictions = model.predict(X_test_nn)
preds = predictions > 0.5
# Out:
# 147/147 [==============================] - 32s 209ms/step

# %%
import seaborn as sns
from sklearn import metrics
from sklearn.metrics import confusion_matrix
corr_pred = metrics.confusion_matrix(y_test, preds)

n_correct = np.int((corr_pred[0][0] + corr_pred[1][1]))
print('> Correct Predictions:', n_correct)
n_wrongs = np.int((corr_pred[0][1] + (corr_pred[1][0])))
print('> Wrong Predictions:', n_wrongs)

sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Blues")
plt.show()

print(metrics.classification_report(y_test, preds, 
                           target_names=["NonViolence", "Violence"]))
# Out:
# > Correct Predictions: 4173
# > Wrong Predictions: 504
#               precision    recall  f1-score   support
#
#  NonViolence       0.89      0.88      0.88      2151
#     Violence       0.90      0.90      0.90      2526
#
#     accuracy                           0.89      4677
#    macro avg       0.89      0.89      0.89      4677
# weighted avg       0.89      0.89      0.89      4677
# /tmp/ipykernel_32/1882902998.py:6: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   n_correct = np.int((corr_pred[0][0] + corr_pred[1][1]))
# /tmp/ipykernel_32/1882902998.py:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   n_wrongs = np.int((corr_pred[0][1] + (corr_pred[1][0])))
